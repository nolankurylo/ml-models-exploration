# %% [markdown]
# # SENG 474
# # Assignment 3 - Problem 3 Retail
# # Nolan Kurylo
# # V00893175
# To execute notebook, ensure ALL cells are run from top to bottom (since imports/df creation are only called once)
#
# References:
#
# 1) https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python
#
# 2) https://www.w3schools.com/python/ref_func_sorted.asp

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Online Retail.xlsx', sheet_name="Online Retail")
# run this cell once, takes ~3 minutes to load in

# %%
from apyori import apriori
pd.options.mode.chained_assignment = None


countries = np.unique(df['Country']) # find all unique countries in the dataset

minsups = {'Austria':0.2, 'Bahrain': 0.5,'Canada': 0.3,'Channel Islands':0.19, 'Cyprus':0.2, 'Denmark':0.3,'European Community':0.5,'Greece':0.4, 'Hong Kong':0.4,
'Iceland':0.5,'Israel':0.3,'Japan':0.2,'Lithuania':0.5, 'Malta':0.4,'Poland':0.2, 'Singapore':0.4,'USA':0.4, 'United Kingdom':0.05} # manually tested minimum support values needed for aprior to run effectively for each country (described in md below)

for country in countries:
    print("Country: " + country)
    # Preprocessing below
    df1 = df[(df['Country'] == country) & (df['StockCode'] != 'POST') & (df['Quantity'] > 0)] # filter to find all transactions for current currently that have an actual quantity and are not postage info
    df1 = df1.dropna() # remove rows with NAN values
    df1['Description'] = df1['Description'].str.strip() # remove any additional whitespace

    numInvoices = len(np.unique(df1['InvoiceNo']))
    if(country == 'Unspecified'): # explained in md below
        print("Not a country, skipping...")
        print() 
        continue
    if(numInvoices <= 2 ): # explained in md below
        print("Not enough invoices to perform Apriori algorithm, moving on to next country...")
        print() 
        continue


    if(country in minsups): # if country was found to need a different minsup value in manual testing
        minsup = minsups[country]

    else: # manual testing showed minsup=0.1 is the best for this country
        minsup = 0.1

    transactions = list(df1.groupby('InvoiceNo')['Description'].apply(list)) # organize all products purchased in the same order to be in their own list

    associations = list(apriori(transactions,min_support=minsup)) # run apriori


    confidence_values = {} # for stroing all records in a dictionary
    i = 0 # unique identifier for dictionary

    for association in associations: # find the support, confidence, lift and aossication rules for each record generated by apriori

        support = association.support
        for rule in association.ordered_statistics:
            
            confidence = rule.confidence
            lift = rule.lift
            left_asc = list(rule.items_base)
            right_asc = list(rule.items_add)
            confidence_values['record_' + str(i)] = {'confidence': confidence, 'lift': lift, 'left_asc': left_asc, 'right_asc':right_asc, 'support': support} # store record for later sorting
            i+=1 

    top5AssociationRecords = sorted(confidence_values.items(), key=lambda record: record[1]['confidence'], reverse=True)[:5] # sort each record to find the top 5 associations according to confidence value
    top5AssociationRecords = dict(top5AssociationRecords) # convert to dictionary for easy looping

    for record in top5AssociationRecords: # loop thru top 5 associations and print their details
        confidence = top5AssociationRecords[record]['confidence']
        support = top5AssociationRecords[record]['support']
        lift = top5AssociationRecords[record]['lift']
        left_asc = top5AssociationRecords[record]['left_asc']
        right_asc = top5AssociationRecords[record]['right_asc']
        print("Association: " + str(left_asc) +" --> " + str(right_asc) + " Support = "+str(support)+" Confidence = "+str(confidence) + " Lift = "+str(lift))
    print()
# Out:
# Country: Australia
# Association: ['ALARM CLOCK BAKELIKE GREEN'] --> ['ALARM CLOCK BAKELIKE RED'] Support = 0.10714285714285714 Confidence = 1.0 Lift = 9.333333333333334
# Association: ['ALARM CLOCK BAKELIKE RED'] --> ['ALARM CLOCK BAKELIKE GREEN'] Support = 0.10714285714285714 Confidence = 1.0 Lift = 9.333333333333334
# Association: ['DOLLY GIRL LUNCH BOX'] --> ['SPACEBOY LUNCH BOX'] Support = 0.10714285714285714 Confidence = 1.0 Lift = 9.333333333333334
# Association: ['SPACEBOY LUNCH BOX'] --> ['DOLLY GIRL LUNCH BOX'] Support = 0.10714285714285714 Confidence = 1.0 Lift = 9.333333333333334
# Association: [] --> ['RED TOADSTOOL LED NIGHT LIGHT'] Support = 0.16071428571428573 Confidence = 0.16071428571428573 Lift = 1.0
#
# Country: Austria
# Association: ['ROUND SNACK BOXES SET OF 4 FRUITS'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.23529411764705882 Confidence = 1.0 Lift = 4.25
# Association: ['ROUND SNACK BOXES SET OF4 WOODLAND'] --> ['ROUND SNACK BOXES SET OF 4 FRUITS'] Support = 0.23529411764705882 Confidence = 1.0 Lift = 4.25
# Association: [] --> ['RETROSPOT TEA SET CERAMIC 11 PC'] Support = 0.23529411764705882 Confidence = 0.23529411764705882 Lift = 1.0
# Association: [] --> ['ROUND SNACK BOXES SET OF 4 FRUITS'] Support = 0.23529411764705882 Confidence = 0.23529411764705882 Lift = 1.0
# Association: [] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.23529411764705882 Confidence = 0.23529411764705882 Lift = 1.0
#
# Country: Bahrain
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Belgium
# Association: ['LUNCH BAG WOODLAND'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.1326530612244898 Confidence = 0.8666666666666667 Lift = 2.235087719298246
# Association: ['ROUND SNACK BOXES SET OF4 WOODLAND', 'SPACEBOY LUNCH BOX'] --> ['DOLLY GIRL LUNCH BOX'] Support = 0.1326530612244898 Confidence = 0.8666666666666667 Lift = 3.692753623188406
# Association: ['ALARM CLOCK BAKELIKE GREEN'] --> ['ALARM CLOCK BAKELIKE RED'] Support = 0.10204081632653061 Confidence = 0.8333333333333334 Lift = 6.282051282051282
# Association: ['ROUND SNACK BOXES SET OF 4 FRUITS'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.1836734693877551 Confidence = 0.8181818181818182 Lift = 2.110047846889952
# Association: ['DOLLY GIRL LUNCH BOX'] --> ['SPACEBOY LUNCH BOX'] Support = 0.1836734693877551 Confidence = 0.782608695652174 Lift = 3.334593572778828
#
# Country: Brazil
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Canada
# Association: ['BUNDLE OF 3 ALPHABET EXERCISE BOOKS'] --> ['BUNDLE OF 3 SCHOOL EXERCISE BOOKS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BUNDLE OF 3 SCHOOL EXERCISE BOOKS'] --> ['BUNDLE OF 3 ALPHABET EXERCISE BOOKS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BUNDLE OF 3 ALPHABET EXERCISE BOOKS'] --> ['COLOURING PENCILS BROWN TUBE'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['COLOURING PENCILS BROWN TUBE'] --> ['BUNDLE OF 3 ALPHABET EXERCISE BOOKS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BUNDLE OF 3 SCHOOL EXERCISE BOOKS'] --> ['COLOURING PENCILS BROWN TUBE'] Support = 0.4 Confidence = 1.0 Lift = 2.5
#
# Country: Channel Islands
# Association: ['DOORMAT WELCOME TO OUR HOME'] --> ['LUNCH BAG RED RETROSPOT'] Support = 0.19230769230769232 Confidence = 1.0 Lift = 3.7142857142857144
# Association: ['GLITTER BUTTERFLY CLIPS'] --> ['IVORY KITCHEN SCALES'] Support = 0.19230769230769232 Confidence = 1.0 Lift = 5.199999999999999
# Association: ['IVORY KITCHEN SCALES'] --> ['GLITTER BUTTERFLY CLIPS'] Support = 0.19230769230769232 Confidence = 1.0 Lift = 5.199999999999999
# Association: ['HOME BUILDING BLOCK WORD'] --> ['LOVE BUILDING BLOCK WORD'] Support = 0.19230769230769232 Confidence = 1.0 Lift = 4.333333333333333
# Association: ['LUNCH BAG PINK POLKADOT'] --> ['LUNCH BAG RED RETROSPOT'] Support = 0.19230769230769232 Confidence = 1.0 Lift = 3.7142857142857144
#
# Country: Cyprus
# Association: ['CANDLEHOLDER PINK HANGING HEART'] --> ['WHITE HANGING HEART T-LIGHT HOLDER'] Support = 0.2 Confidence = 1.0 Lift = 3.0
# Association: ['FELTCRAFT CUSHION OWL'] --> ['LANTERN CREAM GAZEBO'] Support = 0.2 Confidence = 1.0 Lift = 5.0
# Association: ['LANTERN CREAM GAZEBO'] --> ['FELTCRAFT CUSHION OWL'] Support = 0.2 Confidence = 1.0 Lift = 5.0
# Association: ['FELTCRAFT CUSHION OWL'] --> ['PINK FLORAL FELTCRAFT SHOULDER BAG'] Support = 0.2 Confidence = 1.0 Lift = 5.0
# Association: ['PINK FLORAL FELTCRAFT SHOULDER BAG'] --> ['FELTCRAFT CUSHION OWL'] Support = 0.2 Confidence = 1.0 Lift = 5.0
#
# Country: Czech Republic
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Denmark
# Association: ['SPACEBOY LUNCH BOX'] --> ['DOLLY GIRL LUNCH BOX'] Support = 0.3888888888888889 Confidence = 1.0 Lift = 2.25
# Association: ['DOLLY GIRL LUNCH BOX'] --> ['SPACEBOY LUNCH BOX'] Support = 0.3888888888888889 Confidence = 0.8750000000000001 Lift = 2.2500000000000004
# Association: [] --> ['DOLLY GIRL LUNCH BOX'] Support = 0.4444444444444444 Confidence = 0.4444444444444444 Lift = 1.0
# Association: [] --> ['SPACEBOY LUNCH BOX'] Support = 0.3888888888888889 Confidence = 0.3888888888888889 Lift = 1.0
# Association: [] --> ['DOLLY GIRL LUNCH BOX', 'SPACEBOY LUNCH BOX'] Support = 0.3888888888888889 Confidence = 0.3888888888888889 Lift = 1.0
#
# Country: EIRE
# Association: ['PINK REGENCY TEACUP AND SAUCER'] --> ['ROSES REGENCY TEACUP AND SAUCER'] Support = 0.10384615384615385 Confidence = 0.9642857142857143 Lift = 5.698051948051948
# Association: ['PINK REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] Support = 0.1 Confidence = 0.9285714285714286 Lift = 7.100840336134453
# Association: ['GREEN REGENCY TEACUP AND SAUCER'] --> ['ROSES REGENCY TEACUP AND SAUCER'] Support = 0.11923076923076924 Confidence = 0.9117647058823529 Lift = 5.387700534759358
# Association: ['GREEN REGENCY TEACUP AND SAUCER'] --> ['PINK REGENCY TEACUP AND SAUCER'] Support = 0.1 Confidence = 0.7647058823529411 Lift = 7.1008403361344525
# Association: ['ROSES REGENCY TEACUP AND SAUCER'] --> ['GREEN REGENCY TEACUP AND SAUCER'] Support = 0.11923076923076924 Confidence = 0.7045454545454546 Lift = 5.387700534759358
#
# Country: European Community
# Association: ['BISCUIT TIN VINTAGE GREEN'] --> ['BISCUIT TIN VINTAGE RED'] Support = 0.6666666666666666 Confidence = 1.0 Lift = 1.5
# Association: ['BISCUIT TIN VINTAGE RED'] --> ['BISCUIT TIN VINTAGE GREEN'] Support = 0.6666666666666666 Confidence = 1.0 Lift = 1.5
# Association: ['BISCUIT TIN VINTAGE GREEN'] --> ['OFFICE MUG WARMER CHOC+BLUE'] Support = 0.6666666666666666 Confidence = 1.0 Lift = 1.5
# Association: ['OFFICE MUG WARMER CHOC+BLUE'] --> ['BISCUIT TIN VINTAGE GREEN'] Support = 0.6666666666666666 Confidence = 1.0 Lift = 1.5
# Association: ['BISCUIT TIN VINTAGE GREEN'] --> ['OFFICE MUG WARMER POLKADOT'] Support = 0.6666666666666666 Confidence = 1.0 Lift = 1.5
#
# Country: Finland
# Association: ['CHILDRENS CUTLERY POLKADOT GREEN'] --> ['CHILDRENS CUTLERY POLKADOT BLUE'] Support = 0.12195121951219512 Confidence = 1.0 Lift = 5.857142857142857
# Association: ['CHILDRENS CUTLERY POLKADOT BLUE'] --> ['CHILDRENS CUTLERY POLKADOT PINK'] Support = 0.14634146341463414 Confidence = 0.857142857142857 Lift = 3.904761904761904
# Association: ['CHILDRENS CUTLERY POLKADOT BLUE'] --> ['CHILDRENS CUTLERY POLKADOT GREEN'] Support = 0.12195121951219512 Confidence = 0.7142857142857142 Lift = 5.857142857142857
# Association: ['CHILDRENS CUTLERY POLKADOT PINK'] --> ['CHILDRENS CUTLERY POLKADOT BLUE'] Support = 0.14634146341463414 Confidence = 0.6666666666666666 Lift = 3.904761904761904
# Association: [] --> ['CHILDRENS CUTLERY POLKADOT PINK'] Support = 0.21951219512195122 Confidence = 0.21951219512195122 Lift = 1.0
#
# Country: France
# Association: ['SET/6 RED SPOTTY PAPER CUPS', 'SET/20 RED RETROSPOT PAPER NAPKINS'] --> ['SET/6 RED SPOTTY PAPER PLATES'] Support = 0.1015625 Confidence = 0.975 Lift = 7.4879999999999995
# Association: ['SET/6 RED SPOTTY PAPER PLATES', 'SET/20 RED RETROSPOT PAPER NAPKINS'] --> ['SET/6 RED SPOTTY PAPER CUPS'] Support = 0.1015625 Confidence = 0.975 Lift = 6.933333333333334
# Association: ['SET/6 RED SPOTTY PAPER PLATES'] --> ['SET/6 RED SPOTTY PAPER CUPS'] Support = 0.125 Confidence = 0.96 Lift = 6.826666666666666
# Association: ['SET/6 RED SPOTTY PAPER CUPS'] --> ['SET/6 RED SPOTTY PAPER PLATES'] Support = 0.125 Confidence = 0.8888888888888888 Lift = 6.826666666666666
# Association: ['SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES'] --> ['SET/20 RED RETROSPOT PAPER NAPKINS'] Support = 0.1015625 Confidence = 0.8125 Lift = 6.0
#
# Country: Germany
# Association: ['ROUND SNACK BOXES SET OF 4 FRUITS'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.133630289532294 Confidence = 0.8333333333333334 Lift = 3.3407738095238098
# Association: ['ROUND SNACK BOXES SET OF4 WOODLAND'] --> ['ROUND SNACK BOXES SET OF 4 FRUITS'] Support = 0.133630289532294 Confidence = 0.5357142857142857 Lift = 3.3407738095238093
# Association: [] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.24944320712694878 Confidence = 0.24944320712694878 Lift = 1.0
# Association: [] --> ['ROUND SNACK BOXES SET OF 4 FRUITS'] Support = 0.1603563474387528 Confidence = 0.1603563474387528 Lift = 1.0
# Association: [] --> ['PLASTERS IN TIN WOODLAND ANIMALS'] Support = 0.1403118040089087 Confidence = 0.1403118040089087 Lift = 1.0
#
# Country: Greece
# Association: ['BIG DOUGHNUT FRIDGE MAGNETS'] --> ['FRIDGE MAGNETS US DINER ASSORTED'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['FRIDGE MAGNETS US DINER ASSORTED'] --> ['BIG DOUGHNUT FRIDGE MAGNETS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BIG DOUGHNUT FRIDGE MAGNETS'] --> ['KNICKERBOCKERGLORY MAGNET ASSORTED'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['KNICKERBOCKERGLORY MAGNET ASSORTED'] --> ['BIG DOUGHNUT FRIDGE MAGNETS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BIG DOUGHNUT FRIDGE MAGNETS'] --> ['SET OF 4 JAM JAR MAGNETS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
#
# Country: Hong Kong
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Iceland
# Association: ['3D DOG PICTURE PLAYING CARDS'] --> ['AIRLINE BAG VINTAGE JET SET BROWN'] Support = 0.7142857142857143 Confidence = 1.0 Lift = 1.1666666666666667
# Association: ['ALARM CLOCK BAKELIKE CHOCOLATE'] --> ['3D DOG PICTURE PLAYING CARDS'] Support = 0.5714285714285714 Confidence = 1.0 Lift = 1.4
# Association: ['3D DOG PICTURE PLAYING CARDS'] --> ['ALARM CLOCK BAKELIKE RED'] Support = 0.7142857142857143 Confidence = 1.0 Lift = 1.4
# Association: ['ALARM CLOCK BAKELIKE RED'] --> ['3D DOG PICTURE PLAYING CARDS'] Support = 0.7142857142857143 Confidence = 1.0 Lift = 1.4
# Association: ['AIRLINE BAG VINTAGE TOKYO 78'] --> ['AIRLINE BAG VINTAGE JET SET BROWN'] Support = 0.5714285714285714 Confidence = 1.0 Lift = 1.1666666666666667
#
# Country: Israel
# Association: ['BLUE DINER WALL CLOCK'] --> ['CHARLOTTE BAG DOLLY GIRL DESIGN'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['CHARLOTTE BAG DOLLY GIRL DESIGN'] --> ['BLUE DINER WALL CLOCK'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['BLUE DINER WALL CLOCK'] --> ['DOLLY GIRL LUNCH BOX'] Support = 0.4 Confidence = 1.0 Lift = 1.6666666666666667
# Association: ['BLUE DINER WALL CLOCK'] --> ['REGENCY CAKESTAND 3 TIER'] Support = 0.4 Confidence = 1.0 Lift = 1.6666666666666667
# Association: ['BLUE DINER WALL CLOCK'] --> ['SPACEBOY LUNCH BOX'] Support = 0.4 Confidence = 1.0 Lift = 1.6666666666666667
#
# Country: Italy
# Association: ['GINGERBREAD MAN COOKIE CUTTER'] --> ['RETROSPOT TEA SET CERAMIC 11 PC'] Support = 0.11428571428571428 Confidence = 1.0 Lift = 5.0
# Association: ['GINGERBREAD MAN COOKIE CUTTER'] --> ['SET OF 20 KIDS COOKIE CUTTERS'] Support = 0.11428571428571428 Confidence = 1.0 Lift = 7.0
# Association: ['JUMBO STORAGE BAG SUKI'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.11428571428571428 Confidence = 1.0 Lift = 5.833333333333333
# Association: ['LUNCH BAG CARS BLUE'] --> ['LUNCH BAG WOODLAND'] Support = 0.11428571428571428 Confidence = 1.0 Lift = 8.75
# Association: ['LUNCH BAG WOODLAND'] --> ['LUNCH BAG CARS BLUE'] Support = 0.11428571428571428 Confidence = 1.0 Lift = 8.75
#
# Country: Japan
# Association: ['BASKET OF TOADSTOOLS'] --> ['RED SPOTTY BISCUIT TIN'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 3.8000000000000003
# Association: ['BASKET OF TOADSTOOLS'] --> ['SET 3 RETROSPOT TEA,COFFEE,SUGAR'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 4.75
# Association: ['SET 3 RETROSPOT TEA,COFFEE,SUGAR'] --> ['BASKET OF TOADSTOOLS'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 4.75
# Association: ['CHARLOTTE BAG DOLLY GIRL DESIGN'] --> ['LUNCH BAG DOLLY GIRL DESIGN'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 4.75
# Association: ['LUNCH BAG DOLLY GIRL DESIGN'] --> ['CHARLOTTE BAG DOLLY GIRL DESIGN'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 4.75
#
# Country: Lebanon
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Lithuania
# Association: ['FELTCRAFT CUSHION BUTTERFLY'] --> ['FELTCRAFT PRINCESS LOLA DOLL'] Support = 0.5 Confidence = 1.0 Lift = 2.0
# Association: ['FELTCRAFT PRINCESS LOLA DOLL'] --> ['FELTCRAFT CUSHION BUTTERFLY'] Support = 0.5 Confidence = 1.0 Lift = 2.0
# Association: ['FELTCRAFT CUSHION BUTTERFLY'] --> ['FELTCRAFT PRINCESS OLIVIA DOLL'] Support = 0.5 Confidence = 1.0 Lift = 2.0
# Association: ['FELTCRAFT PRINCESS OLIVIA DOLL'] --> ['FELTCRAFT CUSHION BUTTERFLY'] Support = 0.5 Confidence = 1.0 Lift = 2.0
# Association: ['FELTCRAFT CUSHION BUTTERFLY'] --> ['GREY FLORAL FELTCRAFT SHOULDER BAG'] Support = 0.5 Confidence = 1.0 Lift = 2.0
#
# Country: Malta
# Association: ['CERAMIC CAKE STAND + HANGING CAKES'] --> ['CHOC TRUFFLE GOLD TRINKET POT'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['CHOC TRUFFLE GOLD TRINKET POT'] --> ['CERAMIC CAKE STAND + HANGING CAKES'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['CERAMIC CAKE STAND + HANGING CAKES'] --> ['GRAND CHOCOLATECANDLE'] Support = 0.4 Confidence = 1.0 Lift = 1.6666666666666667
# Association: ['CERAMIC CAKE STAND + HANGING CAKES'] --> ['PHOTO FRAME 3 CLASSIC HANGING'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['PHOTO FRAME 3 CLASSIC HANGING'] --> ['CERAMIC CAKE STAND + HANGING CAKES'] Support = 0.4 Confidence = 1.0 Lift = 2.5
#
# Country: Netherlands
# Association: ['PACK OF 60 SPACEBOY CAKE CASES'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 3.7600000000000002
# Association: ['PLASTERS IN TIN SPACEBOY'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.1276595744680851 Confidence = 1.0 Lift = 3.7600000000000002
# Association: ['PLASTERS IN TIN WOODLAND ANIMALS'] --> ['ROUND SNACK BOXES SET OF4 WOODLAND'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 3.7600000000000002
# Association: ['DOLLY GIRL LUNCH BOX', 'ROUND SNACK BOXES SET OF 4 FRUITS'] --> ['SPACEBOY LUNCH BOX'] Support = 0.11702127659574468 Confidence = 1.0 Lift = 3.357142857142857
# Association: ['DOLLY GIRL LUNCH BOX', 'STRAWBERRY LUNCH BOX WITH CUTLERY'] --> ['SPACEBOY LUNCH BOX'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 3.357142857142857
#
# Country: Norway
# Association: ['BLACK KITCHEN SCALES'] --> ['IVORY KITCHEN SCALES'] Support = 0.15151515151515152 Confidence = 1.0 Lift = 4.714285714285714
# Association: ['CHILDS BREAKFAST SET SPACEBOY'] --> ['CHILDS BREAKFAST SET DOLLY GIRL'] Support = 0.18181818181818182 Confidence = 1.0 Lift = 4.125
# Association: ['CHOCOLATE HOT WATER BOTTLE'] --> ['FENG SHUI PILLAR CANDLE'] Support = 0.12121212121212122 Confidence = 1.0 Lift = 8.25
# Association: ['FENG SHUI PILLAR CANDLE'] --> ['CHOCOLATE HOT WATER BOTTLE'] Support = 0.12121212121212122 Confidence = 1.0 Lift = 8.25
# Association: ['CHOCOLATE HOT WATER BOTTLE'] --> ['GROW A FLYTRAP OR SUNFLOWER IN TIN'] Support = 0.12121212121212122 Confidence = 1.0 Lift = 8.25
#
# Country: Poland
# Association: ['SMALL CHINESE STYLE SCISSOR'] --> ['LARGE CHINESE STYLE SCISSOR'] Support = 0.21052631578947367 Confidence = 1.0 Lift = 2.7142857142857144
# Association: ['LARGE CHINESE STYLE SCISSOR'] --> ['SMALL CHINESE STYLE SCISSOR'] Support = 0.21052631578947367 Confidence = 0.5714285714285714 Lift = 2.7142857142857144
# Association: [] --> ['LARGE CHINESE STYLE SCISSOR'] Support = 0.3684210526315789 Confidence = 0.3684210526315789 Lift = 1.0
# Association: [] --> ['SET OF 6 SPICE TINS PANTRY DESIGN'] Support = 0.3157894736842105 Confidence = 0.3157894736842105 Lift = 1.0
# Association: [] --> ['IVORY KITCHEN SCALES'] Support = 0.2631578947368421 Confidence = 0.2631578947368421 Lift = 1.0
#
# Country: Portugal
# Association: ['JUMBO BAG PINK VINTAGE PAISLEY'] --> ['JUMBO SHOPPER VINTAGE RED PAISLEY'] Support = 0.16363636363636364 Confidence = 1.0 Lift = 5.0
# Association: ['SCANDINAVIAN PAISLEY PICNIC BAG'] --> ['PINK VINTAGE PAISLEY PICNIC BAG'] Support = 0.12727272727272726 Confidence = 1.0 Lift = 6.875
# Association: ['PLASTERS IN TIN SPACEBOY'] --> ['PLASTERS IN TIN VINTAGE PAISLEY'] Support = 0.10909090909090909 Confidence = 1.0 Lift = 6.111111111111111
# Association: ['JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'] --> ['JUMBO BAG PINK VINTAGE PAISLEY'] Support = 0.10909090909090909 Confidence = 1.0 Lift = 6.111111111111111
# Association: ['JUMBO BAG PINK VINTAGE PAISLEY', 'JUMBO BAG RED RETROSPOT'] --> ['JUMBO SHOPPER VINTAGE RED PAISLEY'] Support = 0.12727272727272726 Confidence = 1.0 Lift = 5.0
#
# Country: RSA
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Saudi Arabia
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: Singapore
# Association: ['DOORMAT RED RETROSPOT'] --> ['DOORMAT UNION FLAG'] Support = 0.42857142857142855 Confidence = 1.0 Lift = 2.3333333333333335
# Association: ['DOORMAT UNION FLAG'] --> ['DOORMAT RED RETROSPOT'] Support = 0.42857142857142855 Confidence = 1.0 Lift = 2.3333333333333335
# Association: ['DOORMAT RED RETROSPOT'] --> ['LADIES & GENTLEMEN METAL SIGN'] Support = 0.42857142857142855 Confidence = 1.0 Lift = 2.3333333333333335
# Association: ['LADIES & GENTLEMEN METAL SIGN'] --> ['DOORMAT RED RETROSPOT'] Support = 0.42857142857142855 Confidence = 1.0 Lift = 2.3333333333333335
# Association: ['DOORMAT RED RETROSPOT'] --> ['PARTY PIZZA DISH RED RETROSPOT'] Support = 0.42857142857142855 Confidence = 1.0 Lift = 1.75
#
# Country: Spain
# Association: ['ASSORTED COLOUR BIRD ORNAMENT'] --> ['6 RIBBONS RUSTIC CHARM'] Support = 0.10227272727272728 Confidence = 0.7500000000000001 Lift = 4.400000000000001
# Association: ['6 RIBBONS RUSTIC CHARM'] --> ['ASSORTED COLOUR BIRD ORNAMENT'] Support = 0.10227272727272728 Confidence = 0.6000000000000001 Lift = 4.400000000000001
# Association: [] --> ['REGENCY CAKESTAND 3 TIER'] Support = 0.25 Confidence = 0.25 Lift = 1.0
# Association: [] --> ['6 RIBBONS RUSTIC CHARM'] Support = 0.17045454545454544 Confidence = 0.17045454545454544 Lift = 1.0
# Association: [] --> ['JAM MAKING SET WITH JARS'] Support = 0.1590909090909091 Confidence = 0.1590909090909091 Lift = 1.0
#
# Country: Sweden
# Association: ['PACK OF 60 SPACEBOY CAKE CASES'] --> ['PACK OF 72 RETROSPOT CAKE CASES'] Support = 0.11764705882352941 Confidence = 1.0 Lift = 8.5
# Association: ['PACK OF 72 RETROSPOT CAKE CASES'] --> ['PACK OF 60 SPACEBOY CAKE CASES'] Support = 0.11764705882352941 Confidence = 1.0 Lift = 8.5
# Association: [] --> ['SET OF 3 CAKE TINS PANTRY DESIGN'] Support = 0.20588235294117646 Confidence = 0.20588235294117646 Lift = 1.0
# Association: [] --> ['MINI PAINT SET VINTAGE'] Support = 0.17647058823529413 Confidence = 0.17647058823529413 Lift = 1.0
# Association: [] --> ['GUMBALL COAT RACK'] Support = 0.14705882352941177 Confidence = 0.14705882352941177 Lift = 1.0
#
# Country: Switzerland
# Association: ['BLUE POLKADOT BOWL'] --> ['RED RETROSPOT BOWL'] Support = 0.1276595744680851 Confidence = 1.0 Lift = 5.875
# Association: ['CARD CIRCUS PARADE'] --> ['SPACEBOY BIRTHDAY CARD'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 4.7
# Association: ['RED RETROSPOT CHILDRENS UMBRELLA'] --> ['CHILDRENS CUTLERY SPACEBOY'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 5.222222222222222
# Association: ['GREEN POLKADOT BOWL'] --> ['RED RETROSPOT BOWL'] Support = 0.10638297872340426 Confidence = 1.0 Lift = 5.875
# Association: ['GUMBALL COAT RACK'] --> ['PLASTERS IN TIN SPACEBOY'] Support = 0.1276595744680851 Confidence = 1.0 Lift = 2.611111111111111
#
# Country: USA
# Association: ['CARD DOLLY GIRL'] --> ['TEA PARTY BIRTHDAY CARD'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['TEA PARTY BIRTHDAY CARD'] --> ['CARD DOLLY GIRL'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['EMBROIDERED RIBBON REEL SUSIE'] --> ['SET OF 12 FAIRY CAKE BAKING CASES'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['SET OF 12 FAIRY CAKE BAKING CASES'] --> ['EMBROIDERED RIBBON REEL SUSIE'] Support = 0.4 Confidence = 1.0 Lift = 2.5
# Association: ['EMBROIDERED RIBBON REEL SUSIE'] --> ['SET OF 6 RIBBONS VINTAGE CHRISTMAS'] Support = 0.4 Confidence = 1.0 Lift = 2.5
#
# Country: United Arab Emirates
# Not enough invoices to perform Apriori algorithm, moving on to next country...
#
# Country: United Kingdom
# Association: [] --> ['WHITE HANGING HEART T-LIGHT HOLDER'] Support = 0.11327561327561328 Confidence = 0.11327561327561328 Lift = 1.0
# Association: [] --> ['JUMBO BAG RED RETROSPOT'] Support = 0.087000962000962 Confidence = 0.087000962000962 Lift = 1.0
# Association: [] --> ['REGENCY CAKESTAND 3 TIER'] Support = 0.08477633477633478 Confidence = 0.08477633477633478 Lift = 1.0
# Association: [] --> ['ASSORTED COLOUR BIRD ORNAMENT'] Support = 0.07816257816257816 Confidence = 0.07816257816257816 Lift = 1.0
# Association: [] --> ['PARTY BUNTING'] Support = 0.07762145262145262 Confidence = 0.07762145262145262 Lift = 1.0
#
# Country: Unspecified
# Not a country, skipping...

# %% [markdown]
# 3 Retail
#
# The above code runs the Apriori algorithm on each qualifying country in the dataset, grouping all products together that were a part of the same transaction. "Qualifying country" means that some assumptions about the assignment problem had to be made. Through testing the Apriori algorithm on each of the different countries in the dataset, it was determined that due to the quickly increasing complexity of the algorithm, the association rule generation may take too long ( > 10 minutes) for a country. This was discovered to be the case for some countries that had a low number of total transactions (2 or less). What occured here was that the Apriori algorithm generated a lot of rules with the same statistics (support, confidence and lift) so specifying different hyperparamters would not speed up the generation. So for simplicity, these countries were ignored. Furthermore, this occured for the 'Unspecified' country, so it was filtered out of the output.
#
# With needing to run the Apriori algorithm on 30+ countries in this dataset, each country was manually tested to find the optimal minimum support threshold, as seen in the "minsups" list. This was a list created from manual testing Apriori on each country. This improved the overall efficiency of the program while also finding the top 5 associations for each country.
#
# The associations that were found were noticed to have the left hand side of the association being an empty set ([]), with the right hand side being the product description. This means that the association's product description found on the right hand side is commonly found in transactions in general. Also, associations show that both the left and right hand sides contains a list of product descriptions. This means that when the left hand side products are present, the right hand side products are commonly found to be present too (to the degree of statistics of support, confidence and lift).
#
# For finding the "Top 5 Associations" for each country, each record outputed from the Apriori algorithm was stored and later sorted based on each record's confidence value. This means that each of the 5 associations and their corresponding statistics were those with the top 5 highest confidence values.
